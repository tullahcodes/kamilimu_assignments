# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep='\t')

# %%
#SECTION ONE

# %%
#1. Display the last 7 rows of the DataFrame df to get an initial look at the data.
df.tail(7)
# Out:
#       order_id  quantity            item_name  \
# 4615      1832         1   Chicken Soft Tacos
# 4616      1832         1  Chips and Guacamole
# 4617      1833         1        Steak Burrito
# 4618      1833         1        Steak Burrito
# 4619      1834         1   Chicken Salad Bowl
# 4620      1834         1   Chicken Salad Bowl
# 4621      1834         1   Chicken Salad Bowl
#
#                                      choice_description  item_price  revenue
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]        8.75     8.75
# 4616                                                NaN        4.45     4.45
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75    11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75    11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25    11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75     8.75
# ...

# %%
#2. Print a summary of the DataFrame including the index dtype and column dtypes, non-null values, and memory usage.
#  Comment on what you see.
# Answer= The comment is that choice description is the only column with null values while 
#other columns are fully populated

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   str
#  3   choice_description  3376 non-null   str
#  4   item_price          4622 non-null   str
# dtypes: int64(2), str(3)
# memory usage: 180.7 KB

# %%
#3. Determine how many observations have missing item_price in the dataset
int(df['item_price'].isnull().sum())
# Out:
# 0

# %%
#4.Print the names of all columns in the DataFrame.
list(df.columns)
# Out:
# ['order_id',
#  'quantity',
#  'item_name',
#  'choice_description',
#  'item_price',
#  'revenue']

# %%
#5. Identify which item_name appears most frequently in the orders.
df['item_name'].value_counts().idxmax()
# Out:
# 'Chicken Bowl'

# %%
#6. Determine how many distinct item_name values are present in the dataset.
df['item_name'].nunique()
# Out:
# 50

# %%
#7.Create a new DataFrame containing only the rows where the item_name is 'Chicken Bowl'.

chicken_bowl_df=df[df['item_name'] == 'Chicken Bowl']

# %%
#8.The 'item_price' column is currently a string (e.g., '$2.39'). 
# Convert it to a float type. You'll need to remove the dollar sign and then convert the data type.
df['item_price']= df['item_price'].str.replace('$' , '').astype(float)

# %%
#9.After converting 'item_price' to a numerical type, calculate the average item_price across all or
float(df['item_price'].mean())
# Out:
# 7.464335785374297

# %%
# 10. Determine the total number of unique orders in the dataset based on the order_id column.
df['order_id'].nunique()
# Out:
# 1834

# %%
#SECTION TWO

# %%
# 1. Assuming each item_price (after conversion to float) is for a single quantity of that item, calculate the total revenue generated from all orders.
#  Remember that the quantity column indicates how many of that item_name were ordered in that specific line item.
df['revenue']= df['quantity'] * df['item_price']
total_revenue= df ['revenue'].sum()
float(total_revenue)
# Out:
# 39237.02
